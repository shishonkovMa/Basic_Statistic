# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Работа с файлом Flags

# %%
import pandas as pd

# %%
df = pd.read_csv('flags.csv')

# %%
df
# Out:
#                Name  Landmass  Zone  Area  Population  Language  Religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# ..              ...       ...   ...   ...         ...       ...       ...
# 189   Western-Samoa         6     3     3           0         1         1
# 190      Yugoslavia         3     1   256          22         6         6
# 191           Zaire         4     2   905          28        10         5
# 192          Zambia         4     2   753           6        10         5
# 193        Zimbabwe         4     2   391           8        10         5
#
#      Bars  Stripes  Colors  ...  Saltires  Quarters  Sunstars  Crescent  \
# 0       0        3       5  ...         0         0         1         0
# 1       0        0       3  ...         0         0         1         0
# 2       2        0       3  ...         0         0         1         1
# 3       0        0       5  ...         0         0         0         0
# 4       3        0       3  ...         0         0         0         0
# ..    ...      ...     ...  ...       ...       ...       ...       ...
# 189     0        0       3  ...         0         1         5         0
# 190     0        3       4  ...         0         0         1         0
# 191     0        0       4  ...         0         0         0         0
# 192     3        0       4  ...         0         0         0         0
# 193     0        7       5  ...         0         0         1         0
#
#      Triangle  Icon  Animate Text  Topleft  Botright
# 0           0     1        0    0    black     green
# 1           0     0        1    0      red       red
# 2           0     0        0    0    green     white
# 3           1     1        1    0     blue       red
# 4           0     0        0    0     blue       red
# ..        ...   ...      ...  ...      ...       ...
# 189         0     0        0    0     blue       red
# 190         0     0        0    0     blue       red
# 191         0     1        1    0    green     green
# 192         0     0        1    0    green     brown
# 193         1     1        1    0    green     green
#
# [194 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Landmass', 'Zone', 'Area', 'Population', 'Language',
#        'Religion', 'Bars', 'Stripes', 'Colors', 'Red', 'Green', 'Blue', 'Gold',
#        'White', 'Black', 'Orange', 'Mainhue', 'Circles', 'Crosses', 'Saltires',
#        'Quarters', 'Sunstars', 'Crescent', 'Triangle', 'Icon', 'Animate',
#        'Text', 'Topleft', 'Botright'],
#       dtype='object')

# %%
df['Area'].dtype
# Out:
# dtype('int64')

# %%
df['Religion'].value_counts()
# Out:
# 1    60
# 0    40
# 2    36
# 5    27
# 6    15
# 3     8
# 4     4
# 7     4
# Name: Religion, dtype: int64

# %%
len(df['Mainhue'].value_counts())
# Out:
# 8

# %%
df['Mainhue'].mode()
# Out:
# 0    red
# Name: Mainhue, dtype: object

# %%
len(df[df['Mainhue']=='blue'])
# Out:
# 40

# %%
len(df['Mainhue'])
# Out:
# 194

# %%
194/2
# Out:
# 97.0

# %%
pd.crosstab(df['Circles'], df['Bars'])
# Out:
# Bars       0  1  2   3  5
# Circles
# 0        131  6  7  20  1
# 1         27  0  0   0  0
# 2          0  0  0   1  0
# 4          1  0  0   0  0

# %%
131+6+7+20+1+27+1+1
# Out:
# 194

# %%
pd.crosstab(df['Crosses'], df['Bars'])
# Out:
# Bars       0  1  2   3  5
# Crosses
# 0        133  6  6  21  1
# 1         24  0  1   0  0
# 2          2  0  0   0  0
