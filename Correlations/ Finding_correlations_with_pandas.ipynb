# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('hsb2.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline

# %%
df.plot.scatter(x='math', y='read')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr() # by default - Pirson's correlation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.scatter_matrix(df)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr(method='spearman')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr(method='kendall')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['ses'] = df['ses'].astype(pd.api.types.CategoricalDtype(categories=['low', 
                                                           'middle', 
                                                           'high'], 
                                                           ordered=True))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['ses-codes'] = df['ses'].cat.codes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr(method='spearman')

# %% [markdown]
# ![image.png](attachment:image.png)
